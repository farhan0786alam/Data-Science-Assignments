# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON A DATASET

# %% [markdown]
# ### Descriptive Analysis

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### *Reading the data from Dataset Using pandas

# %%
df = pd.read_csv("sales_data_with_discounts_ass_3.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

print("Numerical Columns:", numerical_cols)
print("Categorical Columns:", categorical_cols)
# Out:
# Numerical Columns: ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
# Categorical Columns: ['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model']

# %% [markdown]
# ### Describes The Discount Rate

# %%
df["Discount Rate (%)"].describe()
# Out:
# count    450.000000
# mean      15.155242
# std        4.220602
# min        5.007822
# 25%       13.965063
# 50%       16.577766
# 75%       18.114718
# max       19.992407
# Name: Discount Rate (%), dtype: float64

# %% [markdown]
# #### Printing the No of Rows and Column Using Shape

# %%
df.shape
# Out:
# (450, 13)

# %% [markdown]
# ### Printing the 1st 5 Rows Using Head Function

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %% [markdown]
# ### Printing the last 5 rows using tail function

# %%
df.tail()
# Out:
#            Date       Day  SKU City  Volume         BU  Brand      Model  \
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera  M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva  W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva   W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera  M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera    M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 445      2197.632127
# 446     12939.103758
# 447      2593.102394
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %% [markdown]
# #### We can see Volume,Avg Price,Total Sales Value,Discount Rate (%),Discount Amount,Net Sales Value are numerical data where as Date,day,SKU,City,BU,Brand,Model are categorical data

# %% [markdown]
# #### We are getting statistical data like count, mean, std, min, max, and quartiles of the numerical data using describe function

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# ### We are calculating mode of the numerical data using mode()

# %%
print("mode of volume:\n",df["Volume"].mode()[0])
print("mode of Avg Price:\n",df["Avg Price"].mode()[0])
print("mode of Total Sales Value:\n",df["Total Sales Value"].mode()[0])
print("mode of Discount Rate (%):\n",df["Discount Rate (%)"].mode()[0])
print("mode of Discount Amount:\n",df["Discount Amount"].mode()[0])
print("mode of Net Sales Value:\n",df["Net Sales Value"].mode()[0])
# Out:
# mode of volume:
#  3
# mode of Avg Price:
#  400
# mode of Total Sales Value:
#  24300
# mode of Discount Rate (%):
#  5.007822189204133
# mode of Discount Amount:
#  69.17794228822787
# mode of Net Sales Value:
#  326.97480055470817

# %% [markdown]
# ### We are calculating median of the numerical data using median(

# %%
print("median of volume:\n",df["Volume"].median())
print("median of Avg Price:\n",df["Avg Price"].median())
print("median of Total Sales Value:\n",df["Total Sales Value"].median())
print("median of Discount Rate (%):\n",df["Discount Rate (%)"].median())
print("median of Discount Amount:\n",df["Discount Amount"].median())
print("median of Net Sales Value:\n",df["Net Sales Value"].median())
# Out:
# median of volume:
#  4.0
# median of Avg Price:
#  1450.0
# median of Total Sales Value:
#  5700.0
# median of Discount Rate (%):
#  16.57776564929597
# median of Discount Amount:
#  988.9337332382784
# median of Net Sales Value:
#  4677.788059301853

# %% [markdown]
# ## 2. Data Cleaning

# %%
df.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %% [markdown]
# ### As we can see all the zeroes so can say no null values are present in the dataset..

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Histograms for Numberical Data

# %%
df["Volume"].hist()
print("Volume:",df["Volume"].skew())
# Out:
# Volume: 2.731723626557714

# %% [markdown]
# ### We Can See Right Skewness for Volume

# %%
df["Avg Price"].hist()
print("Avg Price:",df["Avg Price"].skew())
# Out:
# Avg Price: 1.9088730767759727

# %%
df["Total Sales Value"].hist()
print("Total Sales Value:",df["Total Sales Value"].skew())
# Out:
# Total Sales Value: 1.5347293238977937

# %%
df["Discount Rate (%)"].hist()
print("Discount Rate (%):",df["Discount Rate (%)"].skew())
# Out:
# Discount Rate (%): -1.0622943696988825

# %% [markdown]
# ###  We can see left skewness for Discount Rate (%)

# %%
df["Discount Amount"].hist()
print("Discount Amount:",df["Discount Amount"].skew())
# Out:
# Discount Amount: 1.9130377339538271

# %%
df["Net Sales Value"].hist()
print("Net Sales Value:",df["Net Sales Value"].skew())
# Out:
# Net Sales Value: 1.5408217575344376

# %% [markdown]
# ##  Boxplots for numerical data ##

# %%
df["Volume"].plot(kind='box',vert=False,title='Boxplot for Volume')
# Out:
# <Axes: title={'center': 'Boxplot for Volume'}>

# %%
df["Avg Price"].plot(kind='box',vert=False,title='Box plot for Avg Price')
# Out:
# <Axes: title={'center': 'Box plot for Avg Price'}>

# %%
df["Total Sales Value"].plot(kind='box',vert=False,title='Box plot for Total Sales Value')
# Out:
# <Axes: title={'center': 'Box plot for Total Sales Value'}>

# %%
df["Discount Rate (%)"].plot(kind='box',vert=False,title='Box plot for Discount Rate (%)')
# Out:
# <Axes: title={'center': 'Box plot for Discount Rate (%)'}>

# %%
df["Discount Amount"].plot(kind='box',vert=False,title='Box plot for Discount Amount')
# Out:
# <Axes: title={'center': 'Box plot for Discount Amount'}>

# %%
df["Net Sales Value"].plot(kind='box',vert=False,title='Box plot for Net Sales Value')
# Out:
# <Axes: title={'center': 'Box plot for Net Sales Value'}>

# %% [markdown]
# ### Removing outliers:
#    #### Removing outliers:

# %%
Q1_volume=np.percentile(df["Volume"],25)
Q3_volume=np.percentile(df["Volume"],75)
IQR_volume=Q3_volume-Q1_volume
IQR_volume
# Out:
# 3.0

# %%
#upper whisker length 
UW_volume=Q3_volume+(1.5*IQR_volume)
UW_volume
# Out:
# 10.5

# %%
#no of outliers in volume
print("no of outliers:",len(df[df["Volume"]>UW_volume]))
# Out:
# no of outliers: 44

# %%
df[df["Volume"]>UW_volume]
# Out:
#            Date        Day  SKU City  Volume         BU   Brand  \
# 0    01-04-2021   Thursday  M01    C      15    Mobiles   RealU
# 10   01-04-2021   Thursday  F01    C      13       FMCG  Babaji
# 30   02-04-2021     Friday  M01    C      11    Mobiles   RealU
# 40   02-04-2021     Friday  F01    C      29       FMCG  Babaji
# 50   02-04-2021     Friday  L01    C      13  Lifestyle   Jeera
# 70   03-04-2021   Saturday  F01    C      24       FMCG  Babaji
# 71   03-04-2021   Saturday  F02    C      14       FMCG   Vedic
# 80   03-04-2021   Saturday  L01    C      12  Lifestyle   Jeera
# 100  04-04-2021     Sunday  F01    C      25       FMCG  Babaji
# 101  04-04-2021     Sunday  F02    C      15       FMCG   Vedic
# 102  04-04-2021     Sunday  F03    C      11       FMCG   Vedic
# 130  05-04-2021     Monday  F01    C      15       FMCG  Babaji
# 140  05-04-2021     Monday  L01    C      14  Lifestyle   Jeera
# 161  06-04-2021    Tuesday  F02    C      12       FMCG   Vedic
# ...

# %%
df.loc[df["Volume"] > UW_volume, "Volume"] =UW_volume

# %%
df["Volume"].describe()
# Out:
# count    450.000000
# mean       4.604444
# std        2.765759
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       10.500000
# Name: Volume, dtype: float64

# %%
without_outliers_volume=df["Volume"].plot(kind='box',vert=False,title='Box plot for Volume after removing Outliers')
without_outliers_volume
# Out:
# <Axes: title={'center': 'Box plot for Volume after removing Outliers'}>

# %% [markdown]
# #### For Avg Price

# %%
Q1_avg_price=np.percentile(df["Avg Price"],25)
Q3_avg_price=np.percentile(df["Avg Price"],75)
IQR_avg_price=Q3_avg_price-Q1_avg_price
IQR_avg_price
# Out:
# 9635.0

# %%
# UPPER WHISKER LENGTH
UW_avg_price=Q3_avg_price+(1.5*IQR_avg_price)
UW_avg_price
# Out:
# 24552.5

# %%
# no of outliers in avg price
print("no of outliers:",len(df[df["Avg Price"]>UW_avg_price]))
# Out:
# no of outliers: 60

# %%
df[df["Avg Price"]>UW_avg_price]
# Out:
#            Date        Day  SKU City  Volume       BU    Brand Model  \
# 6    01-04-2021   Thursday  M07    C     3.0  Mobiles  Sumsang  S-20
# 7    01-04-2021   Thursday  M08    C     2.0  Mobiles  Sumsang  S-21
# 8    01-04-2021   Thursday  M09    C     2.0  Mobiles   Orange  O-10
# 9    01-04-2021   Thursday  M10    C     3.0  Mobiles   Orange  O-11
# 36   02-04-2021     Friday  M07    C     3.0  Mobiles  Sumsang  S-20
# 37   02-04-2021     Friday  M08    C     1.0  Mobiles  Sumsang  S-21
# 38   02-04-2021     Friday  M09    C     3.0  Mobiles   Orange  O-10
# 39   02-04-2021     Friday  M10    C     3.0  Mobiles   Orange  O-11
# 66   03-04-2021   Saturday  M07    C     4.0  Mobiles  Sumsang  S-20
# 67   03-04-2021   Saturday  M08    C     1.0  Mobiles  Sumsang  S-21
# 68   03-04-2021   Saturday  M09    C     1.0  Mobiles   Orange  O-10
# 69   03-04-2021   Saturday  M10    C     2.0  Mobiles   Orange  O-11
# 96   04-04-2021     Sunday  M07    C     3.0  Mobiles  Sumsang  S-20
# ...

# %%
df.loc[df["Avg Price"] > UW_avg_price, "Avg Price"] = UW_avg_price

# %%
df["Avg Price"].describe()
# Out:
# count      450.000000
# mean      6447.100000
# std       8653.756795
# min        290.000000
# 25%        465.000000
# 50%       1450.000000
# 75%      10100.000000
# max      24552.500000
# Name: Avg Price, dtype: float64

# %%
withoout_outliers_avg_price=df["Avg Price"].plot(kind='box',vert=False,title='box plot for Avg Price after removing outliers')
withoout_outliers_avg_price
# Out:
# <Axes: title={'center': 'box plot for Avg Price after removing outliers'}>

# %% [markdown]
# ### For Total Sales value

# %%
Q1_total_sales_value=np.percentile(df["Total Sales Value"],25)
Q3_total_sales_value=np.percentile(df["Total Sales Value"],75)
IQR_total_sales_value=Q3_total_sales_value-Q1_total_sales_value
IQR_total_sales_value
# Out:
# 50500.0

# %%
# UPPER WHISKER LENGTH
UW_total_sales_value=Q3_total_sales_value+(1.5*IQR_total_sales_value)
UW_total_sales_value
# Out:
# 128950.0

# %%
#no of outliers in volume
print("no of outliers:",len(df[df["Total Sales Value"]>UW_total_sales_value]))
# Out:
# no of outliers: 36

# %%
df[df["Total Sales Value"]>UW_total_sales_value]
# Out:
#            Date        Day  SKU City  Volume       BU    Brand       Model  \
# 0    01-04-2021   Thursday  M01    C    10.5  Mobiles    RealU       RU-10
# 6    01-04-2021   Thursday  M07    C     3.0  Mobiles  Sumsang        S-20
# 9    01-04-2021   Thursday  M10    C     3.0  Mobiles   Orange        O-11
# 30   02-04-2021     Friday  M01    C    10.5  Mobiles    RealU       RU-10
# 36   02-04-2021     Friday  M07    C     3.0  Mobiles  Sumsang        S-20
# 38   02-04-2021     Friday  M09    C     3.0  Mobiles   Orange        O-10
# 39   02-04-2021     Friday  M10    C     3.0  Mobiles   Orange        O-11
# 66   03-04-2021   Saturday  M07    C     4.0  Mobiles  Sumsang        S-20
# 96   04-04-2021     Sunday  M07    C     3.0  Mobiles  Sumsang        S-20
# 126  05-04-2021     Monday  M07    C     3.0  Mobiles  Sumsang        S-20
# 127  05-04-2021     Monday  M08    C     3.0  Mobiles  Sumsang        S-21
# ...

# %%
df.loc[df["Total Sales Value"] > UW_total_sales_value, "Total Sales Value"] = UW_total_sales_value

# %%
df["Total Sales Value"].describe()
# Out:
# count       450.000000
# mean      31407.502222
# std       44686.313870
# min         400.000000
# 25%        2700.000000
# 50%        5700.000000
# 75%       53200.000000
# max      128950.000000
# Name: Total Sales Value, dtype: float64

# %%
without_outliers_total_sales_value=df["Total Sales Value"].plot(kind='box',vert=False,title='Box plot for Total Sales Value after removing Outliers')
without_outliers_total_sales_value
# Out:
# <Axes: title={'center': 'Box plot for Total Sales Value after removing Outliers'}>

# %% [markdown]
# ###  Discount Rate (%)

# %%
Q1_discount_rate=np.percentile(df["Discount Rate (%)"],25)
Q3_discount_rate=np.percentile(df["Discount Rate (%)"],75)
IQR_discount_rate=Q3_discount_rate-Q1_discount_rate
IQR_discount_rate
# Out:
# 4.149655934050962

# %%
# LOWER WISKER LENGTH
LW_discount_rate=Q1_discount_rate-(1.5*IQR_discount_rate)
LW_discount_rate
# Out:
# 7.740578642625298

# %%
#no of outliers in Discount Rate (%)
print("no of outliers:",len(df[df["Discount Rate (%)"]<LW_discount_rate]))
# Out:
# no of outliers: 45

# %%
df[df["Discount Rate (%)"]<LW_discount_rate]
# Out:
#            Date        Day  SKU City  Volume       BU    Brand       Model  \
# 3    01-04-2021   Thursday  M04    C     6.0  Mobiles     YouM  YM-99 Plus
# 7    01-04-2021   Thursday  M08    C     2.0  Mobiles  Sumsang        S-21
# 8    01-04-2021   Thursday  M09    C     2.0  Mobiles   Orange        O-10
# 33   02-04-2021     Friday  M04    C     6.0  Mobiles     YouM  YM-99 Plus
# 36   02-04-2021     Friday  M07    C     3.0  Mobiles  Sumsang        S-20
# 67   03-04-2021   Saturday  M08    C     1.0  Mobiles  Sumsang        S-21
# 69   03-04-2021   Saturday  M10    C     2.0  Mobiles   Orange        O-11
# 93   04-04-2021     Sunday  M04    C     6.0  Mobiles     YouM  YM-99 Plus
# 98   04-04-2021     Sunday  M09    C     2.0  Mobiles   Orange        O-10
# 99   04-04-2021     Sunday  M10    C     2.0  Mobiles   Orange        O-11
# 127  05-04-2021     Monday  M08    C     3.0  Mobiles  Sumsang        S-21
# ...

# %%
df["Discount Rate (%)"].describe()
# Out:
# count    450.000000
# mean      15.155242
# std        4.220602
# min        5.007822
# 25%       13.965063
# 50%       16.577766
# 75%       18.114718
# max       19.992407
# Name: Discount Rate (%), dtype: float64

# %%
df.loc[df["Discount Rate (%)"] < LW_discount_rate, "Discount Rate (%)"] = LW_discount_rate

# %%
without_discount_rate=df["Discount Rate (%)"].plot(kind='box',vert=False,title='Box plot for Discount Rate (%) after removing Outliers')
without_discount_rate
# Out:
# <Axes: title={'center': 'Box plot for Discount Rate (%) after removing Outliers'}>

# %% [markdown]
# ### Discount Amount

# %%
Q1_discount_amount = np.percentile(df["Discount Amount"],25)
Q3_discount_amount = np.percentile(df["Discount Amount"],75)
IQR_discount_amount = Q3_discount_amount-Q1_discount_amount
IQR_discount_amount
# Out:
# 4856.03612280112

# %%
#upper whisker length 
UW_discount_amount=Q3_discount_amount+(1.5*IQR_discount_amount)
UW_discount_amount
# Out:
# 12600.54961088833

# %%
#no of outliers in discount amount
print("no of outliers:",len(df[df["Discount Amount"]>UW_discount_amount]))
# Out:
# no of outliers: 24

# %%
df[df["Discount Amount"]>UW_discount_amount]
# Out:
#            Date        Day  SKU City  Volume       BU    Brand       Model  \
# 0    01-04-2021   Thursday  M01    C    10.5  Mobiles    RealU       RU-10
# 6    01-04-2021   Thursday  M07    C     3.0  Mobiles  Sumsang        S-20
# 9    01-04-2021   Thursday  M10    C     3.0  Mobiles   Orange        O-11
# 30   02-04-2021     Friday  M01    C    10.5  Mobiles    RealU       RU-10
# 38   02-04-2021     Friday  M09    C     3.0  Mobiles   Orange        O-10
# 39   02-04-2021     Friday  M10    C     3.0  Mobiles   Orange        O-11
# 66   03-04-2021   Saturday  M07    C     4.0  Mobiles  Sumsang        S-20
# 90   04-04-2021     Sunday  M01    C     9.0  Mobiles    RealU       RU-10
# 96   04-04-2021     Sunday  M07    C     3.0  Mobiles  Sumsang        S-20
# 180  07-04-2021  Wednesday  M01    C    10.5  Mobiles    RealU       RU-10
# 186  07-04-2021  Wednesday  M07    C     3.0  Mobiles  Sumsang        S-20
# ...

# %%
df.loc[df["Discount Rate (%)"] < LW_discount_rate, "Discount Rate (%)"] = LW_discount_rate

# %%
df["Discount Amount"].describe()
# Out:
# count      450.000000
# mean      3346.499424
# std       4509.902963
# min         69.177942
# 25%        460.459304
# 50%        988.933733
# 75%       5316.495427
# max      25738.022194
# Name: Discount Amount, dtype: float64

# %%
without_outliers_discount_amount=df["Discount Amount"].plot(kind='box',vert=False,title='Box plot for Discount Amount after removing Outliers')
without_outliers_discount_amount
# Out:
# <Axes: title={'center': 'Box plot for Discount Amount after removing Outliers'}>

# %% [markdown]
# ### Net Sale Value

# %%
Q1_net_sales_value=np.percentile(df["Net Sales Value"],25)
Q3_net_sales_value=np.percentile(df["Net Sales Value"],75)
IQR_net_sales_value=Q3_net_sales_value - Q1_net_sales_value
IQR_net_sales_value
# Out:
# 45645.70420627015

# %%
# UPPER WISKER LENGTH
UW_net_sales_value=Q3_net_sales_value+(1.5*IQR_net_sales_value)
UW_net_sales_value
# Out:
# 116316.46916099661

# %%
# NO OF OUTLIERS IN NET SALES VALUE
print("no of outliers",len(df[df["Net Sales Value"]>UW_net_sales_value]))
# Out:
# no of outliers 35

# %%
df[df["Net Sales Value"]>UW_net_sales_value]
# Out:
#            Date        Day  SKU City  Volume       BU    Brand       Model  \
# 0    01-04-2021   Thursday  M01    C    10.5  Mobiles    RealU       RU-10
# 6    01-04-2021   Thursday  M07    C     3.0  Mobiles  Sumsang        S-20
# 9    01-04-2021   Thursday  M10    C     3.0  Mobiles   Orange        O-11
# 36   02-04-2021     Friday  M07    C     3.0  Mobiles  Sumsang        S-20
# 38   02-04-2021     Friday  M09    C     3.0  Mobiles   Orange        O-10
# 39   02-04-2021     Friday  M10    C     3.0  Mobiles   Orange        O-11
# 66   03-04-2021   Saturday  M07    C     4.0  Mobiles  Sumsang        S-20
# 96   04-04-2021     Sunday  M07    C     3.0  Mobiles  Sumsang        S-20
# 126  05-04-2021     Monday  M07    C     3.0  Mobiles  Sumsang        S-20
# 127  05-04-2021     Monday  M08    C     3.0  Mobiles  Sumsang        S-21
# 157  06-04-2021    Tuesday  M08    C     3.0  Mobiles  Sumsang        S-21
# ...

# %%
df.loc[df["Net Sales Value"] > UW_net_sales_value, "Net Sales Value"] = UW_net_sales_value

# %%
df["Net Sales Value"].describe()
# Out:
# count       450.000000
# mean      28189.030727
# std       40858.528122
# min         326.974801
# 25%        2202.208645
# 50%        4677.788059
# 75%       47847.912852
# max      116316.469161
# Name: Net Sales Value, dtype: float64

# %%
without_outliers_net_sales_value=df["Net Sales Value"].plot(kind='box',vert=False,title='Box plot for Net Sales Value after removing Outliers')
without_outliers_net_sales_value
# Out:
# <Axes: title={'center': 'Box plot for Net Sales Value after removing Outliers'}>

# %% [markdown]
# #### Bar Chat of Numerial Data

# %%
df["Day"].value_counts()
# Out:
# Day
# Thursday     90
# Friday       60
# Saturday     60
# Sunday       60
# Monday       60
# Tuesday      60
# Wednesday    60
# Name: count, dtype: int64

# %%
d1=df.groupby('Day')['Net Sales Value'].sum()
d1
# Out:
# Day
# Friday       1.796853e+06
# Monday       1.504943e+06
# Saturday     1.488379e+06
# Sunday       1.738989e+06
# Thursday     2.672245e+06
# Tuesday      1.709564e+06
# Wednesday    1.774092e+06
# Name: Net Sales Value, dtype: float64

# %%
d1.plot(kind='bar',title='Bar chart between day and net sales value\n')
# Out:
# <Axes: title={'center': 'Bar chart between day and net sales value\n'}, xlabel='Day'>

# %% [markdown]
# ### We can see more net sales on thursday

# %% [markdown]
# # See In Pie chart

# %%
d1.plot(kind='pie',title='Pie chart between day and net sales value\n')
# Out:
# <Axes: title={'center': 'Pie chart between day and net sales value\n'}, ylabel='Net Sales Value'>

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Jeera      90
# Gear       60
# Viva       60
# RealU      45
# YouM       45
# Babaji     45
# Vedic      45
# Sumsang    30
# Orange     30
# Name: count, dtype: int64

# %%
d2=df.groupby('Brand')['Total Sales Value'].sum()
d2
# Out:
# Brand
# Babaji      176090
# Gear        107417
# Jeera       516469
# Orange     3436950
# RealU      2855700
# Sumsang    3202650
# Vedic       113700
# Viva        382000
# YouM       3342400
# Name: Total Sales Value, dtype: int64

# %%
d1.plot(kind='bar',title='Bar chart between Brand and total sales value\n')
# Out:
# <Axes: title={'center': 'Bar chart between Brand and total sales value\n'}, xlabel='Day'>

# %% [markdown]
# ### We see orange brand has highest total sales and vedic brand has least total sales

# %%
d3=df.groupby('Brand')['Volume'].sum()
d3
# Out:
# Brand
# Babaji     309.5
# Gear       166.0
# Jeera      442.0
# Orange      68.0
# RealU      265.0
# Sumsang     70.0
# Vedic      290.5
# Viva       242.0
# YouM       219.0
# Name: Volume, dtype: float64

# %%
d3.plot(kind='bar',title='Bar chart between Brand and Volume\n')
# Out:
# <Axes: title={'center': 'Bar chart between Brand and Volume\n'}, xlabel='Brand'>

# %%
df['BU'].value_counts()
# Out:
# BU
# Mobiles      150
# FMCG         150
# Lifestyle    150
# Name: count, dtype: int64

# %%
d4=df.groupby('BU')['Discount Rate (%)'].sum()
d4
# Out:
# BU
# FMCG         2614.890652
# Lifestyle    2620.608026
# Mobiles      1648.700019
# Name: Discount Rate (%), dtype: float64

# %%
d4.plot(kind='bar',title='Bar chart for BU and Discount Rate (%)\n')
# Out:
# <Axes: title={'center': 'Bar chart for BU and Discount Rate (%)\n'}, xlabel='BU'>

# %%
d5=df.groupby('BU')['Discount Amount'].sum()
d5
# Out:
# BU
# FMCG         6.955085e+04
# Lifestyle    1.564994e+05
# Mobiles      1.279875e+06
# Name: Discount Amount, dtype: float64

# %%
d5.plot(kind='bar',title='Bar chart for BU and Discount Amount\n')
# Out:
# <Axes: title={'center': 'Bar chart for BU and Discount Amount\n'}, xlabel='BU'>

# %%
d5.plot(kind='pie',title='Pie chart for BU and Discount Amount\n')
# Out:
# <Axes: title={'center': 'Pie chart for BU and Discount Amount\n'}, ylabel='Discount Amount'>

# %% [markdown]
# ###  Standardization of Numerical Variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    float64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    float64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 45.8+ KB

# %%
numerical_columns=df.select_dtypes(include=['int64','float64']).columns
numerical_columns
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %% [markdown]
# ###  import Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()

# %%
df[numerical_columns] = SS.fit_transform(df[numerical_columns])
df.head()
# Out:
#          Date       Day  SKU City    Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C  2.133995  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C  1.953012  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C  0.867112  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C  0.505145  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C -0.580756  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0   0.653958           2.185257          -0.929603         3.952816
# 1   0.422587           1.559089          -0.953669         1.849014
# 2   1.116699           1.821206          -1.490400         1.622995
# 3   1.579441           1.998190          -1.928310         1.113807
# 4   0.191216          -0.159230           0.688245         0.227852
#
#    Net Sales Value
# 0         2.159293
# 1         1.497922
# 2         1.809543
# 3         2.059311
# 4        -0.202434

# %% [markdown]
# ### Conversion of Categorical Data into Dummy Variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    float64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    float64
#  9   Total Sales Value  450 non-null    float64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.8+ KB

# %% [markdown]
# ### import Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ###  Data Transformation

# %%
from sklearn.preprocessing import OneHotEncoder
df_ohe=pd.get_dummies(df,drop_first=True)
df_ohe.head()
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.133995   0.653958           2.185257          -0.929603         3.952816
# 1  1.953012   0.422587           1.559089          -0.953669         1.849014
# 2  0.867112   1.116699           1.821206          -1.490400         1.622995
# 3  0.505145   1.579441           1.998190          -1.928310         1.113807
# 4 -0.580756   0.191216          -0.159230           0.688245         0.227852
#
#    Net Sales Value  Date_02-04-2021  Date_03-04-2021  Date_04-04-2021  \
# 0         2.159293            False            False            False
# 1         1.497922            False            False            False
# 2         1.809543            False            False            False
# 3         2.059311            False            False            False
# 4        -0.202434            False            False            False
#
#    Date_05-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...

# %%
#Combine standardized numerical and encoded categorical
df_ohe= pd.concat([df_ohe], axis=1)
df_ohe.head()
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.133995   0.653958           2.185257          -0.929603         3.952816
# 1  1.953012   0.422587           1.559089          -0.953669         1.849014
# 2  0.867112   1.116699           1.821206          -1.490400         1.622995
# 3  0.505145   1.579441           1.998190          -1.928310         1.113807
# 4 -0.580756   0.191216          -0.159230           0.688245         0.227852
#
#    Net Sales Value  Date_02-04-2021  Date_03-04-2021  Date_04-04-2021  \
# 0         2.159293            False            False            False
# 1         1.497922            False            False            False
# 2         1.809543            False            False            False
# 3         2.059311            False            False            False
# 4        -0.202434            False            False            False
#
#    Date_05-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...

# %% [markdown]
# ### Conclusion Summary

# %% [markdown]
# ## Summary:
#
# ####  Numerical stats such as mean, median, and std dev revealed the central tendency and variability.
# ####  Histograms and boxplots helped identify skewed distributions and outliers.
# ####  Bar charts revealed category dominance (if any).
# ####  Standardization brought all numerical features to the same scale.
# ####  One-hot encoding converted categorical data into ML-ready format.
# ####  Importance: Data preprocessing ensures uniformity, model readiness, and better interpretation—making analytics and machine learning more robust.
